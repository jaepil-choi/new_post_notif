# %% [markdown]
# The `selenium.webdriver` module provides all the WebDriver implementations. Currently supported WebDriver implementations are Firefox, Chrome, IE and Remote. The `Keys` class provide keys in the keyboard like RETURN, F1, ALT etc.

# %%
from bs4 import BeautifulSoup as bs

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

from IPython.display import Image

# %% [markdown]
# The driver.get method will navigate to a page given by the URL. WebDriver will wait until the page has fully loaded (that is, the “onload” event has fired) before returning control to your test or script. It’s worth noting that if your page uses a lot of AJAX on load then WebDriver may not know when it has completely loaded.:

# %%
driver = webdriver.Chrome()
driver.get("http://pythonscraping.com/pages/javascript/ajaxDemo.html")

# %%
req = driver.page_source
req
# Out:
# '<html><head>\n<title>Some JavaScript-loaded content</title>\n<script src="../js/jquery-2.1.1.min.js"></script>\n\n</head>\n<body>\n<div id="content">Here is some important text you want to retrieve! <p></p><button id="loadedButton">A button to click!</button></div>\n\n<script>\n$.ajax({\n    type: "GET",\n    url: "loadedContent.php",\n    success: function(response){\n\n\tsetTimeout(function() {\n\t    $(\'#content\').html(response);\n\t}, 2000);\n    }\n  });\n\nfunction ajax_delay(str){\n setTimeout("str",2000);\n}\n</script>\n\n</body></html>'

# %%
driver = webdriver.Chrome()
driver.get("https://fcbfi.org/find-jobs/")

# %%
req = driver.page_source
req
# Out:
# '<html lang="en-US" prefix="og: http://ogp.me/ns#" class="wf-loading iphorm-js js_active vc_desktop vc_transform vc_transform wf-josefinslab-n4-loading wf-playfairdisplay-n4-loading wf-breeserif-n4-loading wf-crimsontext-n4-loading wf-oldstandardtt-n4-loading wf-sanchez-n4-loading wf-creteround-n4-loading wf-cardo-n4-loading wf-noticiatext-n4-loading wf-judson-n4-loading wf-unkempt-n4-loading wf-changaone-n4-loading wf-specialelite-n4-loading wf-chewy-n4-loading wf-comfortaa-n4-loading wf-boogaloo-n4-loading wf-luckiestguy-n4-loading wf-cherrycreamsoda-n4-loading wf-lobstertwo-n4-loading wf-righteous-n4-loading wf-squadaone-n4-loading wf-blackopsone-n4-loading wf-happymonkey-n4-loading wf-passionone-n4-loading wf-novasquare-n4-loading wf-metamorphous-n4-loading wf-bevan-n4-loading wf-thegirlnextdoor-n4-loading wf-comingsoon-n4-loading wf-dancingscript-n4-loading wf-pacifico-n4-loading wf-craftygirls-n4-loading wf-calligraffitti-n4-loading wf-rocksalt-n4-loading wf-amaticsc-n4-loading wf-leckerlione-n4-loading wf-tangerine-n4-loading wf-reeniebeanie-n4-loading wf-satisfy-n4-loading wf-gloriahallelujah-n4-loading wf-permanentmarker-n4-loading wf-coveredbyyourgrace-n4-loading wf-walterturncoat-n4-loading wf-patrickhand-n4-loading wf-schoolbell-n4-loading wf-abeezee-n4-loading wf-opensans-n7-loading wf-opensans-n8-loading wf-opensans-i4-loading wf-roboto-n4-active wf-robotocondensed-n4-active wf-raleway-n4-active wf-arvo-n4-active wf-lobster-n4-active wf-fredokaone-n4-active wf-poiretone-n4-active wf-shadowsintolight-n4-active wf-indieflower-n4-active wf-opensans-n6-active wf-opensans-n1-active wf-opensans-n2-active wf-opensans-n3-active wf-roboto-n3-active wf-notoserif-n3-active wf-notoserif-n4-active wf-vollkorn-n3-active wf-vollkorn-n4-active wf-opensans-n4-active wf-nunito-n4-active wf-ptsansnarrow-n4-active wf-ubuntu-n4-active wf-cuprum-n4-active wf-arimo-n4-active wf-sourcesanspro-n4-active wf-yanonekaffeesatz-n4-active wf-francoisone-n4-active wf-ptsans-n4-active wf-opensanscondensed-n4-active wf-lato-n4-active wf-droidsans-n4-active wf-oswald-n4-active wf-oswald-n3-active wf-play-n4-active wf-ptserif-n4-active wf-cantataone-n4-active wf-merriweather-n4-active wf-bitter-n4-active wf-kreon-n4-active wf-rokkitt-n4-active wf-lora-n4-active wf-droidserif-n4-active wf-dosis-n4-inactive wf-abel-n4-active" dir="ltr"><head><meta name="viewport" content="width=0, initial-scale=1">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta charset="UTF-8">\n<div class="fit-vids-style" id="fit-vids-style" style="display: none;">\xad<style>.fluid-width-video-wrapper{width:100%;position:relative;padding:0;}.fluid-width-video-wrapper iframe,.fluid-width-video-wrapper object,.fluid-width-video-wrapper embed {position:absolute;top:0;left:0;width:100%;height:100%;}</style></div><script type="text/javascript" id="www-widgetapi-script" src="https://s.ytimg.com/yts/jsbin/www-widgetapi-vflMm4105/www-widgetapi.js" async=""></script><script src="https://ajax.googleapis.com/ajax/libs/webfont/1/webfont.js" type="text/javascript" async=""></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-MB9LXD7"></script><script type="text/javascript" async="" src="https://www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" integrity="sha384-d/yhnowERvm+7eCU79T/bYjOiMmq4F11ElWYLmt0ktvYEVgqLDazh4+gW9CKMpYW" crossorigin="anonymous" async="" src="https://cdn.amplitude.com/libs/amplitude-5.2.2-min.gz.js"></script><script type="text/javascript" async="" src="https://stats.g.doubleclick.net/dc.js"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script data-cfasync="false" id="ao_optimized_gfonts_config" type="text/javascript">WebFontConfig={google:{families:["Open Sans:greek,latin,greek-ext,vietnamese,cyrillic-ext,latin-ext,cyrillic","Oswald:greek,latin,greek-ext,vietnamese,cyrillic-ext,latin-ext,cyrillic","Droid Sans:greek,latin,greek-ext,vietnamese,cyrilli ...
